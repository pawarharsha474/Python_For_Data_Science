# %% [markdown]
# <a href="https://colab.research.google.com/github/pawarharsha474/Python_For_Data_Science/blob/master/data_visu_matplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing important libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-792ba3a5-009a-4a51-9883-42f67b32544f" name="files[]" multiple disabled />
#      <output id="result-792ba3a5-009a-4a51-9883-42f67b32544f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving big_mart.csv to big_mart.csv

# %%
import io
df = pd.read_csv(io.BytesIO(uploaded['big_mart.csv']))

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight  ... Outlet_Location_Type        Outlet_Type
# 0           FDW58       20.750  ...               Tier 1  Supermarket Type1
# 1           FDW14        8.300  ...               Tier 2  Supermarket Type1
# 2           NCN55       14.600  ...               Tier 3      Grocery Store
# 3           FDQ58        7.315  ...               Tier 2  Supermarket Type1
# 4           FDY38          NaN  ...               Tier 3  Supermarket Type3
#
# [5 rows x 11 columns]

# %%
#mean price based on item type
price_by_item=df.groupby('Item_Type').Item_MRP.mean()[:10]
price_by_item
# Out:
# Item_Type
# Baking Goods             129.052304
# Breads                   142.054893
# Breakfast                132.481526
# Canned                   136.915788
# Dairy                    145.325889
# Frozen Foods             133.409842
# Fruits and Vegetables    143.867282
# Hard Drinks              137.608950
# Health and Hygiene       136.629860
# Household                147.754824
# Name: Item_MRP, dtype: float64

# %%
x=price_by_item.index.tolist()
y=price_by_item.values.tolist()

# %%
#setting  figure size
plt.figure(figsize=(15,10))

#setting title
plt.title('Mean price for each item type')
#set axis labels
plt.xlabel('Item Type')
plt.ylabel('Mean Price')
plt.plot(x,y)

# %% [markdown]
# ## Histogram

# %%
plt.title('Item mrp(price) distribution')

plt.xlabel('Item_MRP')
plt.ylabel('Frequency')
      
plt.hist(df['Item_MRP'],bins=20,color='blue');

# %%
#setting  figure size
plt.figure(figsize=(15,10))

plt.xlabel('Item_Weight')
plt.ylabel('Item_Visibility')

plt.scatter(x,y)
