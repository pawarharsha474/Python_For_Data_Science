# %%
import pandas as pd
import numpy
data_BM=pd.read_csv(r"C:\Users\Mayur.Pawar\Desktop\big_mart.csv")

# %%
data_BM=df.dropna(how="any")
data_BM.head()
# Out:
#    Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0            FDW58       20.750          Low Fat         0.007565
# 5            FDH56        9.800          Regular         0.063817
# 6            FDL48       19.350          Regular         0.082602
# 13           FDU11        4.785          Low Fat         0.092738
# 14           DRL59       16.750               LF         0.021206
#
#                 Item_Type  Item_MRP Outlet_Identifier  \
# 0             Snack Foods  107.8622            OUT049
# 5   Fruits and Vegetables  117.1492            OUT046
# 6            Baking Goods   50.1034            OUT018
# 13                 Breads  122.3098            OUT049
# 14            Hard Drinks   52.0298            OUT013
#
#     Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                        1999      Medium               Tier 1
# 5                        1997       Small               Tier 1
# ...

# %%
sorted_data=data_BM.sort_values(by=['Outlet_Establishment_Year'])
sorted_data[:5]
# Out:
#    Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 14           DRL59       16.750               LF         0.021206
# 5            FDH56        9.800          Regular         0.063817
# 0            FDW58       20.750          Low Fat         0.007565
# 13           FDU11        4.785          Low Fat         0.092738
# 6            FDL48       19.350          Regular         0.082602
#
#                 Item_Type  Item_MRP Outlet_Identifier  \
# 14            Hard Drinks   52.0298            OUT013
# 5   Fruits and Vegetables  117.1492            OUT046
# 0             Snack Foods  107.8622            OUT049
# 13                 Breads  122.3098            OUT049
# 6            Baking Goods   50.1034            OUT018
#
#     Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 14                       1987        High               Tier 3
# 5                        1997       Small               Tier 1
# ...

# %%
import pandas as pd
import numpy
data_BM=pd.read_csv(r"C:\Users\Mayur.Pawar\Desktop\big_mart.csv")
data_BM=df.dropna(how="any")
data_BM.head()
# Out:
#    Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0            FDW58       20.750          Low Fat         0.007565
# 5            FDH56        9.800          Regular         0.063817
# 6            FDL48       19.350          Regular         0.082602
# 13           FDU11        4.785          Low Fat         0.092738
# 14           DRL59       16.750               LF         0.021206
#
#                 Item_Type  Item_MRP Outlet_Identifier  \
# 0             Snack Foods  107.8622            OUT049
# 5   Fruits and Vegetables  117.1492            OUT046
# 6            Baking Goods   50.1034            OUT018
# 13                 Breads  122.3098            OUT049
# 14            Hard Drinks   52.0298            OUT013
#
#     Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                        1999      Medium               Tier 1
# 5                        1997       Small               Tier 1
# ...

# %%
#first Otlet_Establishement_year get sort then Item_Weight
data_BM.sort_values(by=['Outlet_Establishment_Year','Item_Weight'],ascending=False)[:5]
# Out:
#    Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 6            FDL48       19.350          Regular         0.082602
# 0            FDW58       20.750          Low Fat         0.007565
# 13           FDU11        4.785          Low Fat         0.092738
# 5            FDH56        9.800          Regular         0.063817
# 14           DRL59       16.750               LF         0.021206
#
#                 Item_Type  Item_MRP Outlet_Identifier  \
# 6            Baking Goods   50.1034            OUT018
# 0             Snack Foods  107.8622            OUT049
# 13                 Breads  122.3098            OUT049
# 5   Fruits and Vegetables  117.1492            OUT046
# 14            Hard Drinks   52.0298            OUT013
#
#     Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 6                        2009      Medium               Tier 3
# 0                        1999      Medium               Tier 1
# ...

# %%
#sort by index
data_BM.sort_index(inplace=True)
data_BM[:5]
# Out:
#    Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0            FDW58       20.750          Low Fat         0.007565
# 5            FDH56        9.800          Regular         0.063817
# 6            FDL48       19.350          Regular         0.082602
# 13           FDU11        4.785          Low Fat         0.092738
# 14           DRL59       16.750               LF         0.021206
#
#                 Item_Type  Item_MRP Outlet_Identifier  \
# 0             Snack Foods  107.8622            OUT049
# 5   Fruits and Vegetables  117.1492            OUT046
# 6            Baking Goods   50.1034            OUT018
# 13                 Breads  122.3098            OUT049
# 14            Hard Drinks   52.0298            OUT013
#
#     Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                        1999      Medium               Tier 1
# 5                        1997       Small               Tier 1
# ...
